# %% [markdown]
# # 09.06 Key Steps of PCA in Practice

# %% [markdown]
# ## Notes
# - Add theory, derivations, examples, and solved exercises here.
# - Add references at the end.

# %%
# Scratch cell
import numpy as np
