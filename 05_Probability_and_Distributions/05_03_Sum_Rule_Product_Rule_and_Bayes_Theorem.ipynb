# %% [markdown]
# # 05.03 Sum Rule Product Rule and Bayes Theorem

# %% [markdown]
# ## Notes
# - Add theory, derivations, examples, and solved exercises here.
# - Add references at the end.

# %%
# Scratch cell
import numpy as np
